# %%
import pandas as pd
from bs4 import BeautifulSoup as soup
import csv
from pathlib import Path

import datetime

now = datetime.datetime.now()

# %%
import selenium
from selenium import webdriver

# %%
# konfigurasi chromedriver
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--window-size=1420,1080')
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')

browser = webdriver.Chrome(chrome_options=chrome_options)
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: use options instead of chrome_options

# %%
data_folder = Path("data/")
file_data = 'data_kamar_detail-' + now.strftime("%Y%m%d") + '-' + now.strftime("%H%M") + '.csv'
filename = data_folder / file_data
csvFile = open(filename, 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['satker', 'nama', 'alamat', 'prov', 'ruang', 'kelas', 'total_kamar', 'terisi_lk', 'terisi_pr', 'total_terisi','kosong_lk', 'kosong_pr', 'total_kosong', 'waiting_list','last_update','lat','lng'])
# Out:
# 148

# %%
faskes_df = pd.read_csv("Faskes - Rumah Sakit.csv",delimiter=',',encoding='ISO-8859-1')
faskes_df.head()
# Out:
#    Unnamed: 0  prov_id  kode_rs                        nama_unit  \
# 0           1       12  1277015           RS TNI Tk. IV 01.07.03
# 1           2       12  1277011  RS Umum Daerah Padang Sidempuan
# 2           3       12  1276040         RS Tk IV 01.07.02 Binjai
# 3           4       12  1276025             RS Bangkatan PTPN II
# 4           5       12  1275996              RS Umum Sufina Azis
#
#                                       alamat       nama_prov jenis_faskes  \
# 0               Jl. Sudirman No.1 Kelurahan   SUMATERA UTARA  Rumah Sakit
# 1  Jl Dr. F.L. Tobing No. 10,Padangsidimpuan  SUMATERA UTARA  Rumah Sakit
# 2                    Jl. Bandung No.4 Binjai  SUMATERA UTARA  Rumah Sakit
# 3                Jl. Hasanuddin No.40 Binjai  SUMATERA UTARA  Rumah Sakit
# 4                   Jl Karya Baru No.1,Medan  SUMATERA UTARA  Rumah Sakit
#
#         lat        lng
# 0  3.596056  98.675812
# 1  1.419353  99.185211
# 2  3.699319  98.507103
# 3  3.600425  98.485710
# 4  3.590356  98.711342

# %%
faskes_df.shape
# Out:
# (1222, 9)

# %%
global _temp_ruang
for index, row in faskes_df.iterrows():
    satker = str(row['kode_rs'])
    nama_rs = str(row['nama_unit'])
    alamat =  str(row['alamat'])
    prov =  str(row['nama_prov'])
    lat =  row['lat']
    long =  row['lng']

    link = 'http://sirs.yankes.kemkes.go.id/integrasi/data/bed_monitor.php?satker='+satker
    browser.get(link)
    #print(r)
    data = browser.page_source
    url = soup(data,"lxml")
    

    table = url.find('table', attrs={'class':'tbl-responsive table table-striped table-bordered'})
    #print(table)

    if table is not None:
        res = []
        table_rows = table.find_all('tr')

        num_rows = len(table_rows)
        #print(satker+'-'+nama_rs)

        i = 0
        for tr in table_rows:
            _satker = satker
            _nama = nama_rs
            _alamat = alamat
            _prov = prov
            _lat = lat
            _long = long
            _ruang = '-'
            _kelas = '-'
            _total_kamar = '-'
            _terisi_lk = '-'
            _terisi_pr = '-'
            _total_terisi = '-'
            _kosong_lk = '-'
            _kosong_pr = '-'
            _total_kosong = '-'
            _waiting_list = '-'
            _last_update = '-'
            

            if i>1 and i<(num_rows-1):
                
                td = tr.find_all('td')
                #print(td)
                row = [tr.text.strip() for tr in td if tr.text.strip()]
                #print(row)
                #print(str(i)+'-'+str(len(row)))
                if len(row)==12:
                    _temp_ruang = row[1]
                
                #print(_temp_ruang)
                if row:

                    if len(row)==12:
                        _ruang = row[1]
                        _kelas = row[2]
                        _total_kamar = row[3] 
                        _terisi_lk = row[4] 
                        _terisi_pr = row[5]
                        _total_terisi = row[6]
                        _kosong_lk = row[7]
                        _kosong_pr = row[8]
                        _total_kosong = row[9]
                        _waiting_list = row[10]
                        _last_update = row[11]

                    elif len(row)==11:
                        _ruang = _temp_ruang
                        _kelas = row[1] 
                        _total_kamar = row[2] 
                        _terisi_lk = row[3] 
                        _terisi_pr = row[4]
                        _total_terisi = row[5]
                        _kosong_lk = row[6]
                        _kosong_pr = row[7]
                        _total_kosong = row[8]
                        _waiting_list = row[9]
                        _last_update = row[10]
                    elif len(row)==10:
                        _ruang = _temp_ruang
                        if row[0].isnumeric():
                            _kelas = '-'
                        else:
                            _kelas = row[0] 
                        _total_kamar = row[1] 
                        _terisi_lk = row[2] 
                        _terisi_pr = row[3]
                        _total_terisi = row[4]
                        _kosong_lk = row[5]
                        _kosong_pr = row[6]
                        _total_kosong = row[7]
                        _waiting_list = row[8]
                        _last_update = row[9]
                    elif len(row)==9:
                        _ruang = _temp_ruang
                        _kelas = '-'
                        _total_kamar = row[0] 
                        _terisi_lk = row[1] 
                        _terisi_pr = row[2]
                        _total_terisi = row[3]
                        _kosong_lk = row[4]
                        _kosong_pr = row[5]
                        _total_kosong = row[6]
                        _waiting_list = row[7]
                        _last_update = row[8]
                    #print(_waiting_list)
                
                    
                csvWriter.writerow([_satker, _nama, _alamat, _prov, _ruang, _kelas, _total_kamar, _terisi_lk, _terisi_pr, _total_terisi,  _kosong_lk, _kosong_pr, _total_kosong, _waiting_list, _last_update, _lat, _long])
            i = i +1

# %%
csvFile.close()

# %%
dataset = pd.read_csv(filename)
dataset.shape
# Out:
# (30965, 17)

# %%
dataset.head(100)
# Out:
#      satker                               nama  \
# 0   1277011    RS Umum Daerah Padang Sidempuan
# 1   1277011    RS Umum Daerah Padang Sidempuan
# 2   1277011    RS Umum Daerah Padang Sidempuan
# 3   1277011    RS Umum Daerah Padang Sidempuan
# 4   1277011    RS Umum Daerah Padang Sidempuan
# 5   1277011    RS Umum Daerah Padang Sidempuan
# 6   1277011    RS Umum Daerah Padang Sidempuan
# 7   1277011    RS Umum Daerah Padang Sidempuan
# 8   1277011    RS Umum Daerah Padang Sidempuan
# 9   1277011    RS Umum Daerah Padang Sidempuan
# 10  1277011    RS Umum Daerah Padang Sidempuan
# 11  1277011    RS Umum Daerah Padang Sidempuan
# 12  1277011    RS Umum Daerah Padang Sidempuan
# 89                     Jl Sultan Iskandar Muda No.119  SUMATERA UTARA
# 90                     Jl Sultan Iskandar Muda No.119  SUMATERA UTARA
# 91                     Jl Sultan Iskandar Muda No.119  SUMATERA UTARA
# 92  Jl Let. Jend. Jamin Ginting S Km. 10/ Jl. Tali...  SUMATERA UTARA
# 93  Jl Let. Jend. Jamin Ginting S Km. 10/ Jl. Tali...  SUMATERA UTARA
# 94  Jl Let. Jend. Jamin Ginting S Km. 10/ Jl. Tali...  SUMATERA UTARA
# 95                         Jl Kapten Muslim 79, Medan  SUMATERA UTARA
# 96                        Jl. Imam Bonjol No.50,Medan  SUMATERA UTARA
# 97                        Jl. Imam Bonjol No.50,Medan  SUMATERA UTARA
# 98                        Jl. Imam Bonjol No.50,Medan  SUMATERA UTARA
# 99                    Jl M. H. Thamrin No. 105, Medan  SUMATERA UTARA
#
#                 ruang             kelas  total_kamar  terisi_lk  terisi_pr  \
# 0                Umum         super VIP            0          0          0
# 1                Umum           Kelas 3            6          0          0
# 2                Umum           Isolasi            4          0          0
# 3                Anak           Kelas 1            4          0          0
# 4                Anak           Kelas 2            8          0          0
# 5                Anak           Kelas 3           12          0          0
# 6      Penyakit Dalam           Kelas 2           12          0          0
# 7      Penyakit Dalam           Kelas 3           30          0          0
# 8           Kebidanan           Kelas 2            6          0          0
# 9           Kebidanan           Kelas 3           10          0          0
# 10              Bedah           Kelas 2            9          0          0
# 11              Bedah           Kelas 3           10          0          0
# 12               Mata           Kelas 2            4          0          0
# 13               Mata           Kelas 3            6          0          0
# 14                THT           Kelas 2            2          0          0
# 15                THT           Kelas 3            3          0          0
# 16               Paru           Kelas 2            4          0          0
# 17               Paru           Kelas 3           13          0          0
# 18              Saraf           Kelas 2            4          0          0
# 19              Saraf           Kelas 3           12          0          0
# 20               Umum         super VIP            5          2          0
# 21               Umum           Kelas 1           35          0          0
# 22               Umum           Kelas 2           20         10         10
# 23                ICU           Kelas 3            4          0          1
# 24               Umum         super VIP            2          0          0
# 25               Umum               VIP           27          2          2
# 26               Umum           Kelas 1           30          3          2
# 27               Umum           Kelas 2           48          6          5
# 28               Umum           Kelas 3           68         16         11
# 29               Umum      Rawat Khusus            6          0          0
# ..                ...               ...          ...        ...        ...
# 70              Saraf           Kelas 3           40          9          2
# 71              Saraf  Stroke Care Unit            5          2          0
# 72  Isolasi Air Borne           Kelas 1           11          4          7
# 73     Isolasi TB MDR           Kelas 3           10          1          2
# 74                ICU      Rawat Khusus           30          6          7
# 75               NICU      Rawat Khusus            6          2          4
# 76          CVCU/ICCU      Rawat Khusus           13          1          1
# 77                HCU      Rawat Khusus           16          3          3
# 78               Umum         super VIP            4          3          0
# 79               Umum         super VIP            0          0          0
# 80               Umum               VIP            5          2          0
# 81               Umum           Kelas 1           14          7          3
# 82               Umum           Kelas 2           22         11          7
# 83               Umum           Kelas 3           36         12         13
# 84               Umum           Isolasi            2          1          0
# 85               Umum      Rawat Khusus            4          1          0
# 86               Umum               VIP            0          0          0
# 87               Umum         super VIP            2          0          0
# 88               Umum               VIP            2          0          0
# 89               Umum           Kelas 1           10          0          0
# 90               Umum           Kelas 2           20          0          0
# 91               Umum           Kelas 3           30          0          0
# 92               Jiwa           Kelas 1           20          5          3
# 93               Jiwa           Kelas 2           98         61          4
# 94               Jiwa           Kelas 3          323        169         57
# 95               Umum         super VIP            0          0          0
# 96               Umum           Kelas 3            6          0          0
# 97               Anak           Kelas 2            3          0          0
# 98          Kandungan           Kelas 2            3          0          0
# 99               Umum         super VIP           13          0          0
#
#     total_terisi kosong_lk kosong_pr  total_kosong  waiting_list  \
# 0              0         -         -             0           NaN
# 1              0         -         -             6           NaN
# 2              0         -         -             4           NaN
# 3              0         -         -             4           NaN
# 4              0         -         -             8           NaN
# 5              0         -         -            12           NaN
# 6              0         -         -            12           NaN
# 7              0         -         -            30           NaN
# 8              0         -         -             6           NaN
# 9              0         -         -            10           NaN
# 10             0         -         -             9           NaN
# 11             0         -         -            10           NaN
# 12             0         -         -             4           NaN
# 13             0         -         -             6           NaN
# 14             0         -         -             2           NaN
# 15             0         -         -             3           NaN
# 16             0         -         -             4           NaN
# 17             0         -         -            13           NaN
# 18             0         -         -             4           NaN
# 19             0         -         -            12           NaN
# 20             2         2         1             3           NaN
# 21             0         -         -            35           NaN
# 22            20         -         -             0           NaN
# 23             1         2         1             3           NaN
# 24             0         1         1             2           NaN
# 25             4        13        10            23           NaN
# 26             5        15        10            25           NaN
# 27            11        22        15            37           NaN
# 28            27        24        17            41           NaN
# 29             0         3         3             6           NaN
# ..           ...       ...       ...           ...           ...
# 70            11         -         -            29           NaN
# 71             2         -         -             3           NaN
# 72            11         -         -             0           NaN
# 73             3         -         -             7           NaN
# 74            13         -         -            17           NaN
# 75             6         -         -             0           NaN
# 76             2         -         -            11           NaN
# 77             6         -         -            10           NaN
# 78             3         1         0             1           NaN
# 79             0         0         5             5           NaN
# 80             2         -         -             3           NaN
# 81            10         2         2             4           NaN
# 82            18         2         2             4           NaN
# 83            25         5        10            15           NaN
# 84             1         0         1             1           NaN
# 85             1         1         1             2           NaN
# 86             0         1         1             2           NaN
# 87             0         1         1             2           NaN
# 88             0         1         1             2           NaN
# 89             0         -         -            10           NaN
# 90             0         -         -            20           NaN
# 91             0         -         -            30           NaN
# 92             8         5         7            12           NaN
# 93            65        13        20            33           NaN
# 94           226        50        47            97           NaN
# 95             0         -         -             0           NaN
# 96             0         6         6            12           NaN
# 97             0         3         3             6           NaN
# 98             0         0         3             3           NaN
# 99             0         7         6            13           NaN
#
#              last_update       lat        lng
# 0   12/Feb/2019 08:45:56  1.419353  99.185211
# 1   12/Feb/2019 09:03:38  1.419353  99.185211
# 2   12/Feb/2019 09:02:56  1.419353  99.185211
# 3   12/Feb/2019 09:06:30  1.419353  99.185211
# 4   12/Feb/2019 09:05:37  1.419353  99.185211
# 5   12/Feb/2019 09:04:09  1.419353  99.185211
# 6   12/Feb/2019 09:07:28  1.419353  99.185211
# 7   12/Feb/2019 09:06:57  1.419353  99.185211
# 8   12/Feb/2019 09:08:24  1.419353  99.185211
